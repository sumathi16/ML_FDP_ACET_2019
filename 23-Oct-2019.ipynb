# %% [markdown]
# # Global Sales Data
# 1. Read the market data
#     - Observe the data
#         - df.head()
#         - df.tail()
#         - df.sample()
#         - df.info()
#         - df.shape
#         - df.dtypes
#         - df.columns
#         - df.index
#         - df.describe()
#         - df.describe(include=object)
#         - df.describe(include='all')
#     - To Access data column wise or row wise
#         - df[column name]
#         - df[[column1,column2]]
#         - df[column name][:5]
#         - position based indexing
#             - iloc
#         - label based indexing
#             - loc
#         - fancy indexing
#             - selection of columns using a condition
#             - selection of rows using a condition
#     - Plotting
#         - Univariate
#             - matplotlib
#                 - histogram
#                 - boxplot
#                 - bar
#             - seaborn
#                 - distplot
#                 - boxplot
#                 - countplot
#         - Bivariate
#             - matplotlib
#                 - scatter
#             - seaborn
#                 - jointplot
#                 - pairplot
#         - Subplot
#     - Handling Missing Values
#         - column wise deletion - drop,drona
#         - row wise deletion - drop,dropna
#         - Filling the missing values
#             - zero,mean,median(fillna)

# %%
import pandas as pd
path ="Datasets/global_sales_data/market_fact.csv"
market_df = pd.read_csv(path)
market_df.head() # display first five rows
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
market_df.tail()
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 8394              28  374.63           7.69                 0.59
# 8395              20  -74.03           6.92                 0.37
# 8396              39  -70.85           5.35                 0.40
# 8397              23  565.34          30.00                 0.62
# 8398              47  131.39           4.86                 0.38

# %%
market_df.sample(5)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 8324  Ord_2153   Prod_4  SHP_2935   Cust_810  2175.218      0.07
# 5137  Ord_3146   Prod_3  SHP_4367  Cust_1171   278.270      0.02
# 3927  Ord_4518  Prod_10  SHP_6288  Cust_1529  5817.880      0.01
# 138   Ord_4155   Prod_4  SHP_5791  Cust_1423  2211.734      0.02
# 3275  Ord_4498   Prod_2  SHP_6263  Cust_1496  1849.800      0.04
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 8324              13   44.55           3.99                 0.58
# 5137              14  -51.91          12.79                 0.39
# 3927              37 -567.14          66.27                 0.65
# 138               15   80.76           4.99                 0.59
# 3275              43  530.22           4.62                 0.56

# %% [markdown]
# To check number of row and Columns

# %%
market_df.shape
# Out:
# (8399, 10)

# %% [markdown]
# To access rows number

# %%
market_df.shape[0]
# Out:
# 8399

# %%
market_df.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin'],
#       dtype='object')

# %%
market_df.dtypes
# Out:
# Ord_id                  object
# Prod_id                 object
# Ship_id                 object
# Cust_id                 object
# Sales                  float64
# Discount               float64
# Order_Quantity           int64
# Profit                 float64
# Shipping_Cost          float64
# Product_Base_Margin    float64
# dtype: object

# %%
market_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 10 columns):
# Ord_id                 8399 non-null object
# Prod_id                8399 non-null object
# Ship_id                8399 non-null object
# Cust_id                8399 non-null object
# Sales                  8399 non-null float64
# Discount               8399 non-null float64
# Order_Quantity         8399 non-null int64
# Profit                 8399 non-null float64
# Shipping_Cost          8399 non-null float64
# Product_Base_Margin    8336 non-null float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 656.2+ KB

# %%
market_df.describe()
# Out:
#               Sales     Discount  Order_Quantity        Profit  Shipping_Cost  \
# count   8399.000000  8399.000000     8399.000000   8399.000000    8399.000000
# mean    1775.878179     0.049671       25.571735    181.184424      12.838557
# std     3585.050525     0.031823       14.481071   1196.653371      17.264052
# min        2.240000     0.000000        1.000000 -14140.700000       0.490000
# 25%      143.195000     0.020000       13.000000    -83.315000       3.300000
# 50%      449.420000     0.050000       26.000000     -1.500000       6.070000
# 75%     1709.320000     0.080000       38.000000    162.750000      13.990000
# max    89061.050000     0.250000       50.000000  27220.690000     164.730000
#
#        Product_Base_Margin
# count          8336.000000
# mean              0.512513
# std               0.135589
# min               0.350000
# 25%               0.380000
# 50%               0.520000
# 75%               0.590000
# max               0.850000

# %%
market_df.describe(include=object)
# Out:
#          Ord_id Prod_id   Ship_id    Cust_id
# count      8399    8399      8399       8399
# unique     5506      17      7701       1832
# top     Ord_542  Prod_6  SHP_1378  Cust_1140
# freq          6    1225         4         30

# %%
#market_df["Prod_id"].value_counts()
market_df.Prod_id.value_counts()
# Out:
# Prod_6     1225
# Prod_3      915
# Prod_4      883
# Prod_5      788
# Prod_8      758
# Prod_13     633
# Prod_1      546
# Prod_2      434
# Prod_15     386
# Prod_11     361
# Prod_17     337
# Prod_12     288
# Prod_9      246
# Prod_10     189
# Prod_7      179
# Prod_16     144
# Prod_14      87
# Name: Prod_id, dtype: int64

# %%
# How to access sales and Discount columns
market_df[["Sales","Discount"]]
# Out:
#            Sales  Discount
# 0       136.8100      0.01
# 1        42.2700      0.01
# 2      4701.6900      0.00
# 3      2337.8900      0.09
# 4      4233.1500      0.08
# 5       164.0200      0.03
# 6        14.7600      0.01
# 7      3410.1575      0.10
# 8       162.0000      0.01
# 9        57.2200      0.07
# 10     4072.0100      0.01
# 11      465.9000      0.05
# 12      305.0500      0.04
# 13     3364.2480      0.10
# 14     1410.9300      0.08
# 15      460.6900      0.06
# 16      443.4600      0.06
# 17    13255.9300      0.02
# 18      283.1300      0.08
# 19       41.9700      0.05
# 20       57.1700      0.08
# 21       81.2500      0.01
# 22     3202.2500      0.09
# 23       35.6400      0.05
# 24      197.6100      0.08
# 25       38.2600      0.03
# 26      109.5800      0.00
# 27     1062.6900      0.01
# 28     3594.7435      0.05
# 29      139.9800      0.07
# ...          ...       ...
# 8369   1169.2600      0.02
# 8370     62.7800      0.04
# ...

# %%
market_df.values
# Out:
# array([['Ord_5446', 'Prod_16', 'SHP_7609', ..., -30.51, 3.6, 0.56],
#        ['Ord_5406', 'Prod_13', 'SHP_7549', ..., 4.56, 0.93, 0.54],
#        ['Ord_5446', 'Prod_4', 'SHP_7610', ..., 1148.9, 2.5, 0.59],
#        ...,
#        ['Ord_5388', 'Prod_6', 'SHP_7524', ..., -70.85, 5.35, 0.4],
#        ['Ord_5348', 'Prod_15', 'SHP_7469', ..., 565.34, 30.0, 0.62],
#        ['Ord_5459', 'Prod_6', 'SHP_7628', ..., 131.39, 4.86, 0.38]],
#       dtype=object)

# %%
market_df.Sales > 1300
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
# 5       False
# 6       False
# 7        True
# 8       False
# 9       False
# 10       True
# 11      False
# 12      False
# 13       True
# 14       True
# 15      False
# 16      False
# 17       True
# 18      False
# 19      False
# 20      False
# 21      False
# 22       True
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28       True
# 29      False
#         ...
# 8369    False
# 8370    False
# 8371     True
# 8372    False
# 8373    False
# 8374    False
# 8375     True
# 8376    False
# 8377    False
# 8378     True
# 8379    False
# 8380    False
# 8381     True
# 8382    False
# 8383     True
# 8384    False
# 8385    False
# 8386    False
# 8387    False
# 8388    False
# 8389    False
# 8390    False
# 8391     True
# 8392    False
# 8393    False
# 8394     True
# 8395    False
# 8396    False
# 8397     True
# 8398    False
# ...

# %%
market_df.Sales[market_df.Sales > 2000]
# Out:
# 2        4701.6900
# 3        2337.8900
# 4        4233.1500
# 7        3410.1575
# 10       4072.0100
# 13       3364.2480
# 17      13255.9300
# 22       3202.2500
# 28       3594.7435
# 40       4917.6900
# 57       5208.7800
# 64       7640.2250
# 79       5177.4000
# 81       2546.5235
# 82       8374.1320
# 84      21366.5100
# 98       2700.7800
# 107      8901.7800
# 109      2671.2100
# 110      2157.3085
# 121     13070.2000
# 124      3883.4715
# 129      2907.6300
# 133     15337.5800
# 136      2079.4740
# 138      2211.7340
# 141      2027.5500
# 144      2703.3700
# 146      2209.5155
# 148      3005.7400
#            ...
# 8263     7987.4300
# 8271     2823.0370
# 8283    15168.8200
# 8286     5176.2700
# 8289     2731.7300
# 8292    14647.2600
# 8298     6648.5800
# 8304     2272.5600
# 8308     4744.6400
# 8316     2360.4300
# 8317     7535.9600
# 8323     2014.1300
# 8324     2175.2180
# 8329     3636.3700
# 8331     2966.1300
# 8332    10714.7800
# ...

# %%
market_df.Sales[(market_df.Sales > 10000) & 
                (market_df.Sales <70000) ].count()
# Out:
# 291

# %%
market_df.Discount[(market_df.Sales > 10000) & 
                (market_df.Sales <70000) ]
# Out:
# 17      0.02
# 84      0.00
# 121     0.07
# 133     0.10
# 165     0.10
# 189     0.09
# 191     0.08
# 197     0.08
# 199     0.07
# 385     0.05
# 535     0.00
# 549     0.06
# 566     0.10
# 595     0.04
# 597     0.08
# 699     0.01
# 705     0.07
# 708     0.10
# 713     0.06
# 734     0.09
# 755     0.00
# 769     0.06
# 777     0.06
# 781     0.09
# 798     0.09
# 808     0.05
# 832     0.02
# 954     0.00
# 1086    0.01
# 1099    0.07
#         ...
# 7146    0.10
# 7256    0.02
# 7266    0.04
# 7286    0.00
# 7313    0.10
# 7318    0.00
# 7354    0.05
# 7403    0.06
# 7513    0.03
# 7517    0.06
# 7547    0.03
# 7592    0.03
# 7615    0.06
# 7638    0.03
# 7693    0.06
# 7706    0.06
# 7736    0.08
# 7798    0.07
# 7929    0.07
# 7964    0.01
# 8042    0.01
# 8043    0.06
# 8046    0.05
# 8078    0.04
# 8143    0.07
# 8217    0.07
# 8283    0.02
# 8292    0.07
# 8332    0.00
# 8366    0.03
# Name: Discount, Length: 291, dtype: float64

# %%
market_df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-d45288f37196> in <module>()
# ----> 1 market_df[0]
#
# ...

# %% [markdown]
# Position based Indexing (iloc)<br>
# - 0 to length-1<br>
# Label based Indexing(loc)<br>
# - names

# %%
market_df.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin'],
#       dtype='object')

# %%
# Accessing third to 5th columns
market_df.iloc[:,2:5]
# Out:
#        Ship_id    Cust_id       Sales
# 0     SHP_7609  Cust_1818    136.8100
# 1     SHP_7549  Cust_1818     42.2700
# 2     SHP_7610  Cust_1818   4701.6900
# 3     SHP_7625  Cust_1818   2337.8900
# 4     SHP_7664  Cust_1818   4233.1500
# 5     SHP_7608  Cust_1818    164.0200
# 6       SHP_41    Cust_26     14.7600
# 7     SHP_6593  Cust_1641   3410.1575
# 8     SHP_6593  Cust_1641    162.0000
# 9     SHP_6593  Cust_1641     57.2200
# 10    SHP_6615  Cust_1641   4072.0100
# 11    SHP_2637   Cust_708    465.9000
# 12    SHP_4112  Cust_1088    305.0500
# 13    SHP_3093   Cust_839   3364.2480
# 14    SHP_3006   Cust_839   1410.9300
# 15    SHP_3114   Cust_839    460.6900
# 16    SHP_3122   Cust_839    443.4600
# 17    SHP_6228  Cust_1521  13255.9300
# 18    SHP_6171  Cust_1521    283.1300
# 19    SHP_1378   Cust_371     41.9700
# 20    SHP_1378   Cust_371     57.1700
# 21    SHP_1378   Cust_371     81.2500
# 22    SHP_1377   Cust_371   3202.2500
# 23    SHP_1378   Cust_371     35.6400
# ...

# %%
# Accessing 7th column
market_df.iloc[:,6]
# Out:
# 0       23
# 1       13
# 2       26
# 3       43
# 4       35
# 5       23
# 6        5
# 7       48
# 8       33
# 9        8
# 10      43
# 11      38
# 12      27
# 13      15
# 14      10
# 15      48
# 16      30
# 17      25
# 18      45
# 19      12
# 20      18
# 21      11
# 22      44
# 23      10
# 24      13
# 25      22
# 26      13
# 27      28
# 28      38
# 29      33
#         ..
# 8369    41
# 8370    20
# 8371    28
# 8372     7
# 8373    30
# 8374    14
# 8375    47
# 8376    36
# 8377    12
# 8378    20
# 8379    41
# 8380    45
# 8381    25
# 8382    28
# 8383    21
# 8384    10
# 8385    46
# 8386    39
# 8387     4
# 8388    10
# 8389    44
# 8390    47
# 8391    20
# 8392    43
# 8393     9
# 8394    28
# 8395    20
# 8396    39
# 8397    23
# 8398    47
# Name: Order_Quantity, Length: 8399, dtype: int64

# %%
# Access the rows from 100 to 200
market_df.iloc[99:200:4,-1]
# Out:
# 99     0.47
# 103    0.58
# 107     NaN
# 111    0.58
# 115    0.38
# 119    0.37
# 123    0.46
# 127    0.69
# 131    0.38
# 135    0.67
# 139    0.67
# 143    0.59
# 147    0.80
# 151    0.36
# 155    0.43
# 159    0.60
# 163    0.69
# 167    0.35
# 171    0.39
# 175    0.60
# 179    0.56
# 183    0.69
# 187    0.60
# 191    0.71
# 195    0.57
# 199    0.55
# Name: Product_Base_Margin, dtype: float64

# %%
market_df.loc[99:200,:]
# Out:
#        Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 99   Ord_1638   Prod_5  SHP_5892  Cust_1433    755.1900      0.00
# 100  Ord_1638   Prod_8  SHP_5892  Cust_1433    220.7900      0.00
# 101  Ord_1638   Prod_7  SHP_2261   Cust_565    201.1400      0.08
# 102  Ord_1557   Prod_2  SHP_2152   Cust_565   1736.5300      0.10
# 103   Ord_209  Prod_13   SHP_285    Cust_45     30.5100      0.09
# 104   Ord_246   Prod_8   SHP_341    Cust_45    862.2000      0.10
# 105   Ord_122  Prod_17   SHP_165    Cust_45     42.3100      0.06
# 106   Ord_121   Prod_8   SHP_164    Cust_45   1143.4500      0.06
# 107   Ord_250  Prod_15   SHP_346    Cust_45   8901.7800      0.04
# 108   Ord_122   Prod_3   SHP_166    Cust_45    152.6700      0.04
# 109   Ord_139  Prod_17   SHP_186    Cust_45   2671.2100      0.06
# 110   Ord_239   Prod_4   SHP_332    Cust_45   2157.3085      0.00
# 111   Ord_250   Prod_2   SHP_345    Cust_45    324.5500      0.08
# ...

# %%
market_df.loc[:,"Sales":"Shipping_Cost"]
# Out:
#            Sales  Discount  Order_Quantity   Profit  Shipping_Cost
# 0       136.8100      0.01              23   -30.51           3.60
# 1        42.2700      0.01              13     4.56           0.93
# 2      4701.6900      0.00              26  1148.90           2.50
# 3      2337.8900      0.09              43   729.34          14.30
# 4      4233.1500      0.08              35  1219.87          26.30
# 5       164.0200      0.03              23   -47.64           6.15
# 6        14.7600      0.01               5     1.32           0.50
# 7      3410.1575      0.10              48  1137.91           0.99
# 8       162.0000      0.01              33    45.84           0.71
# 9        57.2200      0.07               8   -27.72           6.60
# 10     4072.0100      0.01              43  1675.98           0.99
# 11      465.9000      0.05              38    79.34           4.86
# 12      305.0500      0.04              27    23.12           3.37
# ...

# %%
market_df.loc[:,["Sales","Shipping_Cost"]]
# Out:
#            Sales  Shipping_Cost
# 0       136.8100           3.60
# 1        42.2700           0.93
# 2      4701.6900           2.50
# 3      2337.8900          14.30
# 4      4233.1500          26.30
# 5       164.0200           6.15
# 6        14.7600           0.50
# 7      3410.1575           0.99
# 8       162.0000           0.71
# 9        57.2200           6.60
# 10     4072.0100           0.99
# 11      465.9000           4.86
# 12      305.0500           3.37
# 13     3364.2480          61.76
# 14     1410.9300          36.09
# 15      460.6900           7.29
# 16      443.4600           1.39
# 17    13255.9300          26.00
# 18      283.1300           6.81
# 19       41.9700           4.20
# 20       57.1700           2.31
# 21       81.2500           7.86
# 22     3202.2500          19.99
# 23       35.6400           1.63
# 24      197.6100           7.27
# 25       38.2600           0.70
# 26      109.5800           4.00
# 27     1062.6900           6.66
# ...

# %%
market_df.dtypes == object
# Out:
# Ord_id                  True
# Prod_id                 True
# Ship_id                 True
# Cust_id                 True
# Sales                  False
# Discount               False
# Order_Quantity         False
# Profit                 False
# Shipping_Cost          False
# Product_Base_Margin    False
# dtype: bool

# %%
market_df.columns[market_df.dtypes == object]
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id'], dtype='object')

# %%
market_df.loc[:,market_df.dtypes == object]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818
# 5     Ord_5446   Prod_6  SHP_7608  Cust_1818
# 6       Ord_31  Prod_12    SHP_41    Cust_26
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641
# 8     Ord_4725  Prod_13  SHP_6593  Cust_1641
# 9     Ord_4725   Prod_6  SHP_6593  Cust_1641
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641
# 11    Ord_1925   Prod_6  SHP_2637   Cust_708
# 12    Ord_2978  Prod_16  SHP_4112  Cust_1088
# 13    Ord_2207  Prod_11  SHP_3093   Cust_839
# 14    Ord_2207  Prod_10  SHP_3006   Cust_839
# 15    Ord_2280   Prod_5  SHP_3114   Cust_839
# 16    Ord_2282   Prod_9  SHP_3122   Cust_839
# 17    Ord_4471  Prod_15  SHP_6228  Cust_1521
# 18    Ord_4427   Prod_6  SHP_6171  Cust_1521
# 19     Ord_996  Prod_13  SHP_1378   Cust_371
# ...

# %%
s = "Ord_2448"
s.split('_')
# Out:
# ['Ord', '2448']

# %%
market_df.sort_values(by='Ord_id')
# Out:
#         Ord_id  Prod_id   Ship_id   Cust_id       Sales  Discount  \
# 5858     Ord_1   Prod_1     SHP_1    Cust_1    261.5400      0.04
# 1770    Ord_10   Prod_3    SHP_13   Cust_10     80.6100      0.02
# 5675   Ord_100   Prod_8   SHP_138   Cust_58    121.1200      0.10
# 7384  Ord_1000   Prod_6  SHP_1384  Cust_373    334.7100      0.01
# 5283  Ord_1001   Prod_5  SHP_1385  Cust_374   1981.2600      0.07
# 5250  Ord_1002  Prod_15  SHP_1386  Cust_375   1756.4600      0.01
# 1015  Ord_1003   Prod_9  SHP_1387  Cust_376     49.0400      0.02
# 1017  Ord_1003  Prod_11  SHP_1388  Cust_376   2320.3500      0.00
# 6242  Ord_1004   Prod_3  SHP_1389  Cust_365    139.5400      0.01
# 6243  Ord_1004   Prod_5  SHP_1390  Cust_365    199.5200      0.08
# 6241  Ord_1004   Prod_7  SHP_1391  Cust_365     85.6600      0.04
# 1465  Ord_1005  Prod_16  SHP_1392  Cust_377     15.0000      0.05
# 1464  Ord_1005  Prod_13  SHP_1392  Cust_377     35.4800      0.09
# ...

# %%
market_df.sort_values(by='Sales')
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 6700   Ord_704   Prod_7   SHP_964   Cust_242      2.24      0.01
# 4631   Ord_149   Prod_3  SHP_7028  Cust_1712      3.20      0.09
# 817   Ord_4270   Prod_7  SHP_5959  Cust_1450      3.23      0.06
# 52    Ord_4755  Prod_13  SHP_6628  Cust_1579      3.41      0.06
# 384   Ord_2252   Prod_3  SHP_3064   Cust_881      3.42      0.05
# 5166  Ord_1109  Prod_13  SHP_1531   Cust_429      3.63      0.03
# 4510  Ord_1751  Prod_13  SHP_2427   Cust_597      3.77      0.09
# 45    Ord_4768  Prod_12  SHP_6650  Cust_1579      3.85      0.08
# 3874  Ord_2380   Prod_7  SHP_3268   Cust_953      3.96      0.10
# 2453  Ord_2890   Prod_7  SHP_3987  Cust_1054      4.94      0.10
# 4754  Ord_2506   Prod_7  SHP_5853  Cust_1415      4.97      0.04
# 1359   Ord_104  Prod_16   SHP_142    Cust_62      4.99      0.04
# 4063   Ord_834  Prod_16  SHP_1142   Cust_269      5.06      0.01
# ...

# %%
market_df.sort_values(by='Sales',
                      ascending= False)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 2738  Ord_3084  Prod_17  SHP_4279  Cust_1151  89061.05      0.00
# 3784  Ord_2338  Prod_17  SHP_3207   Cust_932  45923.76      0.07
# 1835  Ord_3875  Prod_17  SHP_5370  Cust_1351  41343.21      0.09
# 2349  Ord_2373  Prod_14  SHP_3259   Cust_942  33367.85      0.01
# 4399  Ord_4614  Prod_14  SHP_6423  Cust_1571  29884.60      0.05
# 7547  Ord_3170  Prod_10  SHP_4400  Cust_1162  29345.27      0.03
# 6037  Ord_3727  Prod_17  SHP_5171  Cust_1310  29186.49      0.05
# 6245   Ord_997  Prod_14  SHP_1379   Cust_365  28761.52      0.04
# 2253  Ord_3143  Prod_14  SHP_4362  Cust_1170  28664.52      0.09
# 8217  Ord_3359  Prod_10  SHP_7245  Cust_1762  28389.14      0.07
# 385   Ord_3707  Prod_17  SHP_5136  Cust_1307  28359.40      0.05
# 7091   Ord_911  Prod_10  SHP_1255   Cust_302  28180.08      0.02
# 7318   Ord_546  Prod_14   SHP_858   Cust_198  27875.54      0.00
# ...

# %%
path = "Datasets/global_sales_data/"
cust_df = pd.read_csv(path+"cust_dimen.csv")
prod_df = pd.read_csv(path+"prod_dimen.csv")
order_df = pd.read_csv(path+"orders_dimen.csv")
ship_df = pd.read_csv(path+"shipping_dimen.csv")

# %%
cust_df.head()
# Out:
#         Customer_Name Province   Region Customer_Segment Cust_id
# 0  MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS  Cust_1
# 1        BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER  Cust_2
# 2       CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE  Cust_3
# 3      CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER  Cust_4
# 4        CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE  Cust_5

# %%
prod_df.head()
# Out:
#   Product_Category            Product_Sub_Category Prod_id
# 0  OFFICE SUPPLIES          STORAGE & ORGANIZATION  Prod_1
# 1  OFFICE SUPPLIES                      APPLIANCES  Prod_2
# 2  OFFICE SUPPLIES  BINDERS AND BINDER ACCESSORIES  Prod_3
# 3       TECHNOLOGY    TELEPHONES AND COMMUNICATION  Prod_4
# 4        FURNITURE              OFFICE FURNISHINGS  Prod_5

# %%
df1 = pd.merge(market_df,cust_df,how="inner", 
              on='Cust_id')
df1.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin',
#        'Customer_Name', 'Province', 'Region', 'Customer_Segment'],
#       dtype='object')

# %%
print(market_df.shape,df1.shape)
# Out:
# (8399, 10) (8399, 14)

# %%
help(pd.merge)
# Out:
# Help on function merge in module pandas.core.reshape.merge:
#
# merge(left, right, how='inner', on=None, left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True, indicator=False, validate=None)
#     Merge DataFrame objects by performing a database-style join operation by
#     columns or indexes.
#
#     If joining columns on columns, the DataFrame indexes *will be
#     ignored*. Otherwise if joining indexes on indexes or indexes on a column or
#     columns, the index will be passed on.
#
#     Parameters
#     ----------
#     left : DataFrame
#     right : DataFrame
#     how : {'left', 'right', 'outer', 'inner'}, default 'inner'
#         * left: use only keys from left frame, similar to a SQL left outer join;
#           preserve key order
#         * right: use only keys from right frame, similar to a SQL right outer join;
#           preserve key order
# ...

# %%
df2 = pd.merge(df1,prod_df,how='inner',
              on='Prod_id')
df2.shape
# Out:
# (8399, 16)

# %%
df3 = pd.merge(df2,ship_df,how='inner',
              on='Ship_id')
df3.shape
# Out:
# (8399, 19)

# %%
master_df = pd.merge(df3,order_df,how='inner',
              on='Ord_id')
master_df.shape
# Out:
# (8399, 22)

# %%
master_df.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin',
#        'Customer_Name', 'Province', 'Region', 'Customer_Segment',
#        'Product_Category', 'Product_Sub_Category', 'Order_ID_x', 'Ship_Mode',
#        'Ship_Date', 'Order_ID_y', 'Order_Date', 'Order_Priority'],
#       dtype='object')

# %%
group_obj = master_df.groupby('Customer_Segment')
group_obj.Sales.sum()
# Out:
# Customer_Segment
# CONSUMER          3.063611e+06
# CORPORATE         5.498905e+06
# HOME OFFICE       3.564764e+06
# SMALL BUSINESS    2.788321e+06
# Name: Sales, dtype: float64

# %%
group_obj.Sales.sum()[group_obj.Sales.sum()==
                      group_obj.Sales.sum().max()].index
# Out:
# Index(['CORPORATE'], dtype='object', name='Customer_Segment')

# %%
group_obj.Sales.sum().argmax()
# Out:
# C:\Users\krish\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   """Entry point for launching an IPython kernel.
# 'CORPORATE'

# %%
group_obj = master_df.groupby(['Customer_Segment',
                               'Product_Category'])
group_obj.Sales.sum()
# Out:
# Customer_Segment  Product_Category
# CONSUMER          FURNITURE           1.128807e+06
#                   OFFICE SUPPLIES     6.913822e+05
#                   TECHNOLOGY          1.243422e+06
# CORPORATE         FURNITURE           1.862841e+06
#                   OFFICE SUPPLIES     1.341316e+06
#                   TECHNOLOGY          2.294749e+06
# HOME OFFICE       FURNITURE           1.285346e+06
#                   OFFICE SUPPLIES     9.600544e+05
#                   TECHNOLOGY          1.319364e+06
# SMALL BUSINESS    FURNITURE           9.015968e+05
#                   OFFICE SUPPLIES     7.600098e+05
#                   TECHNOLOGY          1.126714e+06
# Name: Sales, dtype: float64

# %% [markdown]
# Plotting
# - Univariate Analysis
# - Bivariate Analysis

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(master_df['Sales'],bins=5)
# Out:
# (array([8.305e+03, 9.100e+01, 2.000e+00, 0.000e+00, 1.000e+00]),
#  array([2.2400000e+00, 1.7814002e+04, 3.5625764e+04, 5.3437526e+04,
#         7.1249288e+04, 8.9061050e+04]),
#  <a list of 5 Patch objects>)

# %%
plt.hist([3,4,7,8,3,3,10,20])
# Out:
# (array([4., 0., 2., 0., 1., 0., 0., 0., 0., 1.]),
#  array([ 3. ,  4.7,  6.4,  8.1,  9.8, 11.5, 13.2, 14.9, 16.6, 18.3, 20. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(master_df['Profit'],bins=3)
# Out:
# (array([6.780e+02, 7.719e+03, 2.000e+00]),
#  array([-14140.7 ,   -353.57,  13433.56,  27220.69]),
#  <a list of 3 Patch objects>)

# %%
new = master_df['Profit'][(master_df['Profit']>0) & 
                   (master_df['Profit']<2000)]
plt.hist(new)
# Out:
# (array([2198.,  578.,  329.,  213.,  137.,  125.,   85.,   68.,   55.,
#           43.]),
#  array([8.00000e-02, 1.99740e+02, 3.99400e+02, 5.99060e+02, 7.98720e+02,
#         9.98380e+02, 1.19804e+03, 1.39770e+03, 1.59736e+03, 1.79702e+03,
#         1.99668e+03]),
#  <a list of 10 Patch objects>)

# %%
plt.boxplot(master_df['Sales'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23fa9911240>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23fa993ee80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23fa993e0f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x23fa9946710>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23fa9946b38>],
#  'means': []}

# %%
import numpy as np
plt.boxplot(np.log(master_df['Sales']))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23fa998dcf8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23fa99979b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23fa998dba8>],
#  'medians': [<matplotlib.lines.Line2D at 0x23fa9997eb8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x23fa99a0668>],
#  'means': []}

# %%
q1 = np.quantile(master_df['Sales'],0.25)
q2 = np.quantile(master_df['Sales'],0.5)
q3 = np.quantile(master_df['Sales'],0.75)
IQR = 1.5*(q3-q1)  #Inter Quartile Range
#(q1-IQR)> x <(q3+IQR) 
# The values in this range are not outliers
print((q1-IQR),(q3+IQR))
master_df["Sales"][(master_df["Sales"]<(q1-IQR)) |
                  (master_df["Sales"]>(q3+IQR))].count()
# Out:
# -2205.9925000000003 4058.5075000000006
# 1042

# %%
plt.scatter(master_df['Profit'], master_df['Sales'])

# %%
v = master_df['Prod_id'].value_counts()

# %%
i = master_df['Prod_id'].value_counts().index

# %%
plt.bar(i,v)
# Out:
# <BarContainer object of 17 artists>

# %%
import seaborn as sns

# %%
sns.distplot(np.log(master_df['Sales']))
# Out:
# C:\Users\krish\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(np.log(master_df['Sales']),hist=False)
# Out:
# C:\Users\krish\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(np.log(master_df['Sales'][:100]),
             
             hist=False,rug=True)
# Out:
# C:\Users\krish\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.subplot(2,2,1)
a = np.linspace(20,40,6)
b = 3.5 *a +8
plt.plot(a,b,'-')
plt.title('line')

plt.subplot(2,2,2)
plt.plot(a,b**2,'*')
plt.title('square')

plt.subplot(2,2,3)
plt.plot(a,b**3,'^')
plt.title('cube')

plt.subplot(2,2,4)
plt.plot(a,(b**2)+(3*b),'+')
plt.title('poly')
# Out:
# Text(0.5,1,'poly')

# %%
numerical = master_df.columns[master_df.dtypes != object]
#numerical.shape
for i in range(5):
    #print(i)
    plt.subplot(4,2,i+1)
    plt.hist(master_df[numerical[i]])

# %%
numerical[5]
# Out:
# 'Product_Base_Margin'

# %%
master_df['Product_Base_Margin'].min()
# Out:
# 0.35

# %%
master_df['Product_Base_Margin'].max()
# Out:
# 0.85

# %%
master_df['Product_Base_Margin'].isnull().sum()
# Out:
# 63

# %%
#sns.jointplot('Sales','Profit',master_df)
sns.jointplot(master_df['Sales'],master_df['Profit'])
# Out:
# C:\Users\krish\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(master_df.dropna())

# %%
master_df.dropna().corr()
# Out:
#                         Sales  Discount  Order_Quantity    Profit  \
# Sales                1.000000 -0.019750        0.218430  0.584664
# Discount            -0.019750  1.000000       -0.008315 -0.038365
# Order_Quantity       0.218430 -0.008315        1.000000  0.194572
# Profit               0.584664 -0.038365        0.194572  1.000000
# Shipping_Cost        0.430897 -0.003303       -0.011156 -0.024519
# Product_Base_Margin  0.156759  0.004079        0.007839 -0.112985
# Order_ID_x          -0.007739 -0.003319        0.010389 -0.004926
# Order_ID_y          -0.007739 -0.003319        0.010389 -0.004926
#
#                      Shipping_Cost  Product_Base_Margin  Order_ID_x  \
# Sales                     0.430897             0.156759   -0.007739
# Discount                 -0.003303             0.004079   -0.003319
# Order_Quantity           -0.011156             0.007839    0.010389
# Profit                   -0.024519            -0.112985   -0.004926
# ...

# %% [markdown]
# Missing Values

# %%
master_df.isnull().sum()
# Out:
# Ord_id                   0
# Prod_id                  0
# Ship_id                  0
# Cust_id                  0
# Sales                    0
# Discount                 0
# Order_Quantity           0
# Profit                   0
# Shipping_Cost            0
# Product_Base_Margin     63
# Customer_Name            0
# Province                 0
# Region                   0
# Customer_Segment         0
# Product_Category         0
# Product_Sub_Category     0
# Order_ID_x               0
# Ship_Mode                0
# Ship_Date                0
# Order_ID_y               0
# Order_Date               0
# Order_Priority           0
# dtype: int64

# %% [markdown]
# Removing the column

# %%
new_df1 = master_df.drop('Product_Base_Margin',axis = 1)
print(new_df1.shape,master_df.shape)
print(new_df1.isnull().sum().sum())
# Out:
# (8399, 21) (8399, 22)
# 0

# %%
new_df4 = master_df.dropna(axis=1)
new_df4.shape,master_df.shape
# Out:
# ((8399, 21), (8399, 22))

# %% [markdown]
# Removing the rows

# %%
mask = master_df['Product_Base_Margin'].isnull()
new_df2 = master_df.drop(master_df.index[mask],axis = 0)
new_df2.shape,master_df.shape
# Out:
# ((8336, 22), (8399, 22))

# %%
new_df3 = master_df.dropna()
new_df3.shape,master_df.shape
# Out:
# ((8336, 22), (8399, 22))

# %% [markdown]
# Filling the null values

# %%
new_df4 = master_df.fillna(0)
new_df4.shape,master_df.shape
# Out:
# ((8399, 22), (8399, 22))

# %%
mask = master_df['Product_Base_Margin'].isnull() 
master_df['Product_Base_Margin'][mask] = \
            master_df['Product_Base_Margin'].mean()
# Out:
# C:\Users\krish\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
master_df['Product_Base_Margin'][mask]
# Out:
# 1006    0.512513
# 1222    0.512513
# 1535    0.512513
# 1539    0.512513
# 1563    0.512513
# 1637    0.512513
# 1776    0.512513
# 1794    0.512513
# 2586    0.512513
# 2914    0.512513
# 3137    0.512513
# 3309    0.512513
# 3527    0.512513
# 3540    0.512513
# 3752    0.512513
# 3896    0.512513
# 4011    0.512513
# 4013    0.512513
# 4797    0.512513
# 5007    0.512513
# 5045    0.512513
# 5174    0.512513
# 5535    0.512513
# 5590    0.512513
# 5629    0.512513
# 5665    0.512513
# 5670    0.512513
# 5672    0.512513
# 5698    0.512513
# 5716    0.512513
#           ...
# 6048    0.512513
# 6067    0.512513
# 6177    0.512513
# 6663    0.512513
# 6873    0.512513
# 6881    0.512513
# 6919    0.512513
# 6922    0.512513
# 6923    0.512513
# 6925    0.512513
# 6939    0.512513
# 6943    0.512513
# 6953    0.512513
# 6958    0.512513
# 7054    0.512513
# 7081    0.512513
# 7216    0.512513
# 7271    0.512513
# 7759    0.512513
# 7793    0.512513
# 7812    0.512513
# ...
